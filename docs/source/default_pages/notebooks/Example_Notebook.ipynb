# %% [markdown]
# This is an
# # Example Jupyter Notebook
#
# This notebook shows up in this sphinx documentation because of two reasons:
# - the notebook is located in "Equayes/docs/source/notebooks"
#   (unfortunately there is no straightforward way to link to other locations)
# - the name of this notebook ("Example_Notebook.ipynb") is linked the TOC tree in above folders' file "notebooks.md"
#
# ```{note}
# Both points above a necessary in order to enable sphinx keeping track of multiple notebooks.
# It is easy, but has to be done!
# ```{warning}
# Other notebook locations than inside  "Equayes/docs/source/notebooks" are currently not supported - **unfortunately**.Don't lose time trying this unless you explicitely want to solve this issue. So either you work on your notebooks directly in this folder, or you copy notebooks from your `notebooks` directory into this docs folder.
# ```

# %% [markdown]
# ## Installation check
#
#
#
# If you have **pip installed** the equayes package correctly, the following import should be engough and work fine.
#
# ```{important}
# If the package is not **pip installed** but git-cloned only, this won't work (see next cell).
# ```

# %%
import equayes

# %% [markdown]
# As this is an ECML package, standard utilities are provided to make our data-science lifes easier.
# Let's utilize a well working logging mechanism first:

# %%
from equayes.utils import log
logger = log.getLogger("Example_Notebook")

# Test it straight away
logger.info("Now the import works fine :)")

# %% [markdown]
# ```{note}
# The folder where log files are stored is defined as ```log_path``` in ```Equayes/equayes/config/config.yml```
# which is by default ```reports/logs```
# ```

# %% [markdown]
# ### Configuration
# **Project related configuration** happens in just one config file.
# Also **Logging configuration** is easily done in just one config file.
#
# So the whole project configuration should - by now - just happen in two places:
# - [config.yml file](../../../equayes/config/config.yml)
# - [logging_config.yml file](../../../equayes/config/logging_config.yml)
#
#
#
# ```{Note}
# Adding and changing values there means, the `from equayes.utils import CONFIG, CONSTANTS` package dictionaries
# ```

# %%
from equayes.utils import CONFIG, CONSTANTS

logger.info(f"available CONFIG dictionary:\n{CONFIG}\n")
logger.info(f"available CONSTANTS dictionary:\n{CONFIG}\n")
